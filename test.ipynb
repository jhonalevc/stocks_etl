# %%
import pandas as pd
import numpy as np
import Stock_Prices as sp
import datetime
from sqlalchemy import create_engine

# Define variables for sql connection.
user= 'postgres'
password = 'Alejandro123!'
ip = '34.71.5.205'

#Connect to the DB.
engine = create_engine(
    'postgresql+psycopg2://' + user + ':'+ password +'@'+ ip +'/postgres')



s = pd.read_html(r'C:\Users\AlejandroVelez\OneDrive - Accelirate, Inc\Documents\Development\Web Scraping\table.html')[0]
s['Quantity'] = np.random.random_integers(100,1000,len(s))
s
# Out:
# C:\Users\AlejandroVelez\AppData\Local\Temp\ipykernel_22336\3152536054.py:19: DeprecationWarning: This function is deprecated. Please call randint(100, 1000 + 1) instead
#   s['Quantity'] = np.random.random_integers(100,1000,len(s))
#     Symbol                 Company Name                        Industry  \
# 0        A         Agilent Technologies  Life Sciences Tools & Services
# 1       AA                        Alcoa                 Metals & Mining
# 2      AAC             Ares Acquisition              Blank Check / SPAC
# 3     AACG        ATA Creativity Global   Diversified Consumer Services
# 4     AACI         Armada Acquisition I              Blank Check / SPAC
# ..     ...                          ...                             ...
# 495   ASND              Ascendis Pharma                   Biotechnology
# 496   ASNS             Actelis Networks                   Biotechnology
# 497    ASO  Academy Sports and Outdoors                Specialty Retail
# ...

# %%
s.to_sql(schema= 'public', con= engine,name='portfolio',index = False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\AlejandroVelez\OneDrive - Accelirate, Inc\Documents\Development\Web Scraping\StocksETL\test.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AlejandroVelez/OneDrive%20-%20Accelirate%2C%20Inc/Documents/Development/Web%20Scraping/StocksETL/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> s.to_sql(schema= 'public', con= engine,name='portfolio',index = 'False')
#
# File c:\Users\AlejandroVelez\anaconda3\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
# ...
